# %%
def chatbot():
    print("Welcome to CodeAlpha Chatbot!")
    print("Type 'bye' to exit.\n")

    while True:
        user = input("You: ").lower()

        if user == "hello":
            print("Bot: Hi! Nice to meet you.")
        elif user == "how are you":
            print("Bot: I'm fine, thanks for asking!")
        elif user == "what is your name":
            print("Bot: I am CodeAlpha ChatBot.")
        elif user == "bye":
            print("Bot: Goodbye! Have a nice day.")
            break
        else:
            print("Bot: Sorry, I don't understand that.")

chatbot()
# Out:
# Welcome to CodeAlpha Chatbot!
# Type 'bye' to exit.
# You:  hello
# Bot: Hi! Nice to meet you.
# You:  How are you
# Bot: I'm fine, thanks for asking!
# You:  What is your name?
# Bot: Sorry, I don't understand that.
# You:  What is your name
# Bot: I am CodeAlpha ChatBot.
# You:  bye
# Bot: Goodbye! Have a nice day.

# %%
import os
print([f for f in os.listdir() if f.endswith(".ipynb")])
# Out:
# ['BasicChatbot.ipynb', 'disease--prediction-Copy1.ipynb', 'disease--prediction.ipynb', 'Disease_prediction.ipynb']
